# %% [markdown]
# # NARMA10 task
#
# This task consists in predicting the output of a 10-th order non-linear autoregressive moving average (NARMA) system.
# - [Reference paper](https://doi.org/10.1016/j.neunet.2011.02.002)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import itertools

import torch
from torch import cuda, zeros, Tensor, optim
from torch.nn import Module, ModuleList, Sequential, Linear, Tanh, MSELoss, RNN

from sklearn.metrics import mean_squared_error
# from grid import GS

# %% [markdown]
# The input of the system is a sequence of elements 𝑥(𝑡) randomly chosen according to a uniform distribution over [0, 0.5].
#
# Given the input value 𝑥(𝑡), the task is to predict the corresponding value of 𝑦(𝑡).
#
# - Import the dataset from the .csv file *NARMA10.csv*, where the first row represents the input and the second row represents the
# target output. Different columns represent different time-steps.
# - Split the data into training (the first 5000 time steps), and test set (remaining time steps). Note that for model selection you will use the data in the training set, with a further split in training (first 4000 samples) and validation (last 1000 samples).
#     - For the sake of problem understanding, you can try to first visualize the timeseries data

# %%
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
dset = pd.read_csv('./data/NARMA10.csv', header=None).to_numpy()
x = dset[0]
y = dset[1]
x_test = x[:5000]
train = x[5000:] 

x_train = train[:4000]
x_val = train[4000:]

y_test = y[:5000]
train_y = y[5000:] 

y_train = train_y[:4000]
y_val = train_y[4000:]

x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((4000,), (4000,), (1000,), (1000,), (5000,), (5000,))

# %%
# plot_ts(x_train,x_val,x_test, "NARMA10 input values")

limit1=int(x_train.shape[0])
limit2=int(x_train.shape[0]+x_val.shape[0])
limit3=int(limit2+x_test.shape[0])

plt.figure(figsize=(12,5), dpi=200)
plt.plot(range(0,limit1), x_train, color="indigo", linewidth=0.2, label="training set") 
plt.plot(range(limit1,limit2), x_val, color="purple", linewidth=0.2, label="validation set") 
plt.plot(range(limit2,limit3), x_test, color="violet", linewidth=0.2, label="test set") 

plt.title('NARMA10 input values')
plt.xlabel("Time steps")
plt.ylabel("Values")
plt.legend()
plt.grid(color = 'green', linestyle = '--', linewidth = 0.2)
#plt.savefig(str('plots/timeseries.jpeg'), edgecolor='black', dpi=400, transparent=True)
plt.show()

# %% [markdown]
# **Remember:** when training an RNN you want to make sure to keep the last hidden state of your RNN after the training session, and use it as initial hidden state of the validation session.
# Same applies when transitioning to the test session

# %%
# This class `GS` implements a grid search algorithm to find the best model configuration for either a
# TDNN or RNN neural network based on specified parameters and datasets.
class GS:
    
    def __init__(self, parameters:dict, Xset, Yset, neuralnet:str):
        self.Xset=Xset
        self.Yset=Yset
        param_grid = self.grid(parameters) #self, 
        min_loss, best_model = self.search(param_grid, neuralnet) #self, 
        self.min_loss = min_loss
        self.best_model = best_model # the best model discovered

    # @staticmethod
    def grid(self, params):
        param_names=list(params.keys())
        param_values=list(params.values())
        param_combinations=list(itertools.product(*param_values))
        
        param_grid=[]
        for combination in param_combinations:
            param_grid.append(dict(zip(param_names, combination)))
        return param_grid 
        
    @staticmethod
    def get_optimizer(model, optimizer_name, lr):
        if optimizer_name == 'adam':
            return optim.Adam(model.parameters(), lr=lr)
        elif optimizer_name == 'sgd':
            return optim.SGD(model.parameters(), lr=lr)
        else:
            raise ValueError("Unknown optimizer: {}".format(optimizer_name))
        
    # @staticmethod
    def search(self, param_grid:tuple, neuralnet:str):#, Xset, Yset):
        predictions={}  
        for pg in param_grid:
            print(f'Parameters: {pg}')
            if neuralnet=='TDNN':
                model=TDNN_model(
                    window=pg['window'],
                    layers=pg['layers'],
                    input_dim=self.Xset.shape[0],
                    epochs=pg['epochs'],
                    hidden_dim=pg['hiddens']       
                )
            elif neuralnet=='RNN':
                model=RNN_model(
                    input_dim=self.Xset.size(0), #self.Xset.shape[1]
                    layers=pg['layers'],
                    epochs=pg['epochs'],
                    hidden_dim=pg['hiddens']
                ) 
            optimizer = self.get_optimizer(model, pg['opt'], pg['lr'])      
            loss, y_pred=model.train(self.Xset, self.Yset, optimizer)#
            predictions[min(loss)]=[pg, y_pred] 
        
        
        # predictions=dict(sorted(predictions.items()))
        # print(next(iter(predictions.items())))
        # min_loss=list(predictions.keys())[0]
        min_loss = min(predictions.keys())
        # best_model=list(predictions.values())[0]
        best_model = predictions[min_loss]
        
        return min_loss, best_model

# %%
# With this function, you obtain a 1x[window_size]x4000 Torch Tensor 
# to pass to the TDNN as preprocessed input data

def input_prep(window:int, input_data:np.array):
        input_len=len(input_data)
        prep_input=torch.zeros([1, input_len, window])
        for i in range(0, input_len):
            #if((i+window) <= input_len): 
                tmp=input_data[i:i+window]
                #prep_input[0,i,:]=tmp 
                for j in tmp:
                    prep_input[0,i,:]=j
        # print('TENSOR:', prep_input.shape)
        return prep_input

# %%
def plot_results(tr_y, tr_y_pred, ts_y, ts_y_pred, nn):
    # Plotting the results
    plt.figure(figsize=(12, 6))
    plt.suptitle(nn)

    plt.subplot(2, 1, 1)
    plt.plot(tr_y, label="True",linewidth=0.2)
    plt.plot(tr_y_pred, label="Predicted", linewidth=0.2)
    plt.title('Training Data')
    plt.xlabel('Time')
    plt.ylabel('Output')
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(ts_y, label="True", linewidth=0.2)
    plt.plot(ts_y_pred, label="Predicted", linewidth=0.2)
    plt.title('Test Data')
    plt.xlabel('Time')
    plt.ylabel('Output')
    plt.legend()

    plt.tight_layout()
    plt.savefig(str('plots/'+nn+'_results.jpeg'), edgecolor='black', dpi=400, transparent=True)
    plt.show()
    
#target = target_data.reshape(1, -1, 1)
#y_pred = y_pred.detach().numpy()

def loss_plot(tr_losses, ts_losses):
    # Plotting the results
    plt.figure(figsize=(12, 6))
    plt.suptitle(nn)
    
    # plt.subplot(2, 1, 1)
    plt.title('Loss history')
    plt.plot([loss for loss in tr_losses], label="Training")
    plt.plot([loss for loss in ts_losses], label="Test")
    plt.xlabel('step')
    plt.ylabel('loss')
    plt.grid()
    
    plt.tight_layout()
    plt.savefig(str('plots/'+nn+'_loss.jpeg'), edgecolor='black', dpi=400, transparent=True)
    plt.show()

# %%
############################
#   TDNN: every epoch you pass all the matrix input (window)
#   RNN: every epoch you pass a timestep and let it run
############################

# %% [markdown]
# ## Time-delay neural network

# %%
''' 
This is a PyTorch neural network model class that implements a simple TDNN architecture with a
specified number of hidden layers and dimensions. 
'''

class TDNN_model(torch.nn.Module):
    def __init__(self, window:int, layers:int, input_dim:int, epochs:int, hidden_dim:int): 
        super(TDNN_model, self).__init__()
        
        hidden_layers = [] #torch.nn.ModuleList()
        # hidden = torch.nn.ModuleList([torch.nn.ReLU(), torch.nn.Linear(hidden_dim, hidden_dim)])
        # self.all_layers.append([hidden for i in range(1,layers)])
        
        for _ in range(layers):
            hidden_layers.append(torch.nn.Dropout(0.5)) 
            hidden_layers.append(torch.nn.Linear(hidden_dim, hidden_dim))
            hidden_layers.append(torch.nn.ReLU())
        
        self.model = torch.nn.Sequential(
            torch.nn.Linear(window, hidden_dim), #window*input_dim
            torch.nn.ReLU(),
            *hidden_layers,
            torch.nn.Linear(hidden_dim, 1),
            torch.nn.Tanh()
            ) 
        
        
        self.window=window   
        self.epochs=epochs   
        
                
    def train(self, input_data:Tensor, target_data:Tensor, optimizer):
        #create sequences of data
        timesteps=input_prep(self.window, input_data)
        #pass them to the model        
        #then to the optimizer
        target = torch.tensor(target_data, dtype=torch.float32).reshape(1, -1, 1)
        # target=input_prep(self.window, target_data) #self.window
        losses=[]
        for e in range(1,self.epochs):
            optimizer.zero_grad()
            y_pred = self.model(timesteps)
            # print(f'Target shape: {target.shape}, Predicted shape: {y_pred.shape}')
            mse = MSELoss()
            # y_pred = y_pred.detach().numpy().squeeze()
            loss = mse(y_pred, target) 
            #  (torch.tensor(target_data)).unsqueeze(0).unsqueeze(-1)
            # loss = float(loss)
            # print(f'Loss: {loss}')
            if loss is not None:
                # optimizer.zero_grad()
                loss.backward()
                optimizer.step() 
                losses.append(loss.item())
        print(f'Loss: {min(losses)} \n-----------------------------------------------------')
                #catch loss and history and get them back to the grid search for storage and evaluation
        return(losses, y_pred)

# %%
# # adam=torch.optim.Adam()
# # sgd=torch.optim.SGD()
params={
    'epochs':[100, 500], #1000
    'layers':[1, 2, 5], #, 3, 5 
    'hiddens':[64, 128],  #, 256
    'window':[5,10], #15, 20, 50
    'lr':[0.001, 0.01], # 0.1, 0.0001, 
    'opt':['adam', 'sgd']
}

# %%
nn='TDNN'
grid_search=GS(params, x_train, y_train, nn) 
best_loss, best_model=grid_search.min_loss, grid_search.best_model
tr_ypred = best_model[1]


grid_search_val=GS(params, x_val, y_val, nn) 
best_loss_val, best_model_val=grid_search.min_loss, grid_search.best_model
best_params = best_model_val[0]


print('\nBest training loss: ', best_loss, '\n Best training model: ', best_model[0])

print('Cross validation: \n best loss on validation: ', best_loss_val, '\n best model parametrization based on validation: ',best_params)
# Out:
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.010172134265303612
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.06325580924749374
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007302909158170223
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.009547529742121696
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007607236970216036
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.03338214382529259
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007263804320245981
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008042984642088413
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007879788987338543
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.08172713965177536
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007612138520926237
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.009366447106003761
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.008217019028961658
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.029866142198443413
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007275682408362627
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.009128354489803314
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007995148189365864
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.044457294046878815
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007249355781823397
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008516351692378521
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007390807382762432
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.03331838175654411
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.00723539013415575
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008426058106124401
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007734585553407669
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.04830976948142052
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007251043803989887
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008883651345968246
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007616186048835516
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.07192355394363403
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0072466786950826645
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008561690337955952
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007684137672185898
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.11742834746837616
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007249702233821154
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.0077406843192875385
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.008432582020759583
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.051614440977573395
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0072503117844462395
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.00769347557798028
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.0074822986498475075
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.03598536178469658
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007249598391354084
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008254204876720905
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.00779410544782877
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.04249798133969307
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0072489851154387
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.00810347218066454
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007272147107869387
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.013540992513298988
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007239692844450474
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.00806052703410387
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007231153082102537
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.01340540312230587
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007219902239739895
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007810881827026606
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.0072419298812747
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.011377583257853985
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007237367797642946
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008267860859632492
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007210783194750547
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.0103374682366848
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007220412604510784
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008042124100029469
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007255488075315952
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.01493146177381277
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007245925720781088
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007936862297356129
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007237216457724571
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.012773040682077408
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007223889231681824
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.0077551668509840965
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.00724393455311656
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.01045851781964302
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007242169231176376
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007673350628465414
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007217311765998602
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.010389968752861023
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007221902720630169
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007809302769601345
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007241578307002783
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.011592317372560501
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007241148501634598
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007421009708195925
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007244136184453964
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.016490422189235687
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007244217209517956
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007451134268194437
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007239558268338442
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.01239361148327589
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007236809935420752
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007295601535588503
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.0072340527549386024
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.010645067319273949
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0072474051266908646
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.0072628227062523365
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.008795646950602531
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.05351744964718819
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007371882442384958
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.009275038726627827
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007651270367205143
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.017179438844323158
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007358932867646217
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.010030095465481281
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.008132005110383034
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.03446494787931442
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0073598953895270824
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008808612823486328
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007348532788455486
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.028890691697597504
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.00734981382265687
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008807902224361897
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.01047440990805626
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.010673652403056622
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007372155319899321
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008427129127085209
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007468818221241236
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.03522224724292755
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007357715163379908
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008330662734806538
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007925412617623806
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.04840981587767601
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0073746582493186
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008925785310566425
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.00781963486224413
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.06394198536872864
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007360619492828846
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008866106159985065
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007913772948086262
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.022954922169446945
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007386311888694763
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.00816847663372755
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.008251852355897427
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.07388986647129059
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007369207683950663
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.00832176860421896
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007562920451164246
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.042010631412267685
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007372621912509203
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007835933938622475
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007389653008431196
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.08477970957756042
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007383091375231743
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007738846819847822
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007351210340857506
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.008997907862067223
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007345317862927914
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.0077017731964588165
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007364328019320965
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.012973477132618427
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.00732430350035429
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007820663042366505
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007372433319687843
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.009982791729271412
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007350274361670017
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008417478762567043
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007331567350775003
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.00934632122516632
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.00732665928080678
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008205431513488293
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007344014476984739
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.013423439115285873
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007380045484751463
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.00805207621306181
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007336412090808153
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.015622426755726337
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0073507241904735565
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.00755341025069356
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.0073475963436067104
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.010812698863446712
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0073580932803452015
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008561745285987854
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.00732688931748271
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.009918764233589172
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0073534902185201645
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 2, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007773768622428179
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007351864129304886
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.019235996529459953
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007388260681182146
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007374426815658808
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.007362646516412497
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.009749387390911579
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0073706903494894505
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 64, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007376862224191427
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.00734427897259593
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.010825619101524353
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0073594567365944386
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 5, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007350177504122257
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.0073625510558485985
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.011087966151535511
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007363365963101387
# -----------------------------------------------------
# Parameters: {'epochs': 500, 'layers': 5, 'hiddens': 128, 'window': 10, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007361532188951969
# -----------------------------------------------------
#
# Best training loss:  0.007210783194750547
#  Best training model:  {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}
# Cross validation:
#  best loss on validation:  0.007210783194750547
#  best model parametrization based on validation:  {'epochs': 500, 'layers': 1, 'hiddens': 128, 'window': 10, 'lr': 0.001, 'opt': 'adam'}

# %% [markdown]
# ##### Final steps

# %%
x_whole = np.concatenate([x_train, x_val])
y_whole = np.concatenate([y_train, y_val])

# %%
mse = MSELoss()

print('Whole training set:')
tdnn = TDNN_model(best_params['window'], best_params['layers'], x_whole.shape[0], best_params['epochs'], best_params['hiddens'] )
optimizer = GS.get_optimizer(tdnn, best_params['opt'], best_params['lr'])  
# whole_loss, whole_ypred=tdnn.train(x_test, y_test,optimizer) 
timesteps=input_prep(best_params['window'], x_whole)
whole_ypred = tdnn.model(timesteps)
# target = torch.tensor(y_whole, dtype=torch.float32).reshape(1, -1, 1)
whole_loss = mse(whole_ypred, target) 
print(whole_loss.item())

print('Test:')
tdnn = TDNN_model(best_params['window'], best_params['layers'], x_test.shape[0], best_params['epochs'], best_params['hiddens'])
optimizer = GS.get_optimizer(tdnn, best_params['opt'], best_params['lr'])  
# test_loss, test_ypred=tdnn.train(x_test, y_test,optimizer) 
timesteps=input_prep(best_params['window'], x_test)
test_ypred = tdnn.model(timesteps)
# target = torch.tensor(y_test, dtype=torch.float32).reshape(1, -1, 1)
test_loss = mse(test_ypred, target) 
print(test_loss.item())
# Out:
# Whole training set:
# 0.08369249105453491
# Test:
# 0.06704877316951752

# %%
y_whole.shape, whole_ypred.shape, y_test.shape, test_ypred.shape
# Out:
# ((5000,), torch.Size([1, 5000, 1]), (5000,), torch.Size([1, 5000, 1]))

# %%
whole_ypred_NP = whole_ypred.detach().numpy().astype('float64')
test_ypred_NP = test_ypred.detach().numpy().astype('float64')

# %%
whole_ypred_f=whole_ypred_NP.flatten()
test_ypred_f=test_ypred_NP.flatten()
whole_ypred_f.shape, test_ypred_f.shape
# Out:
# ((5000,), (5000,))

# %%
y_whole.shape, whole_ypred_f.shape, y_test.shape, test_ypred_f.shape
# Out:
# ((5000,), (5000,), (5000,), (5000,))

# %%
plot_results(y_whole, whole_ypred_f, y_test, test_ypred_f, nn)

# %% [markdown]
# ## Recurrent neural network

# %%
''' 
This is a PyTorch neural network model class that implements a simple RNN architecture with a
specified number of hidden layers and dimensions. 
'''

class RNN_model(torch.nn.Module):
    def __init__(self, input_dim:int, layers:int, epochs:int, hidden_dim:int):
        super(RNN_model, self).__init__()
        self.hidden_dim = hidden_dim
        self.layers = layers

        self.rnn = torch.nn.RNN(input_dim, hidden_dim, layers, nonlinearity='tanh', bias=False, batch_first=True)
        self.readout = torch.nn.Linear(hidden_dim, 1)
        
        self.epochs=epochs
        
        
    def forward(self, x):
        h0 = torch.zeros(self.layers, x.size(0), self.hidden_dim)
        out, hn = self.rnn(x, h0) 
        out = self.readout(out) 
        h0=hn
        return out
    
    
    
    def train(self, input_data:Tensor, target_data:Tensor, optimizer):
        losses=[]
        for e in range(1,self.epochs):
            optimizer.zero_grad()
            y_pred= self.forward(input_data)
            mse = MSELoss()
            loss = mse(y_pred, target_data)
            if loss is not None:
                # optimizer.zero_grad()
                loss.backward()
                optimizer.step()  
                losses.append(loss.item())  
        print(f'Loss: {min(losses)} \n-----------------------------------------------------')       
                ###catch loss and history and get them back to the grid search for storage and evaluation
        return(losses, y_pred)

# %%
# adam=torch.optim.Adam()
# sgd=torch.optim.SGD()
params={
    'epochs':[100], #1000
    'layers':[2,5],#10, 3 
    'hiddens':[64, 128], #64, 256
    'lr':[0.001, 0.01], #0.1
    'opt':['adam', 'sgd']
}


nn='RNN'
x_tr =  torch.from_numpy(np.reshape(x_train, (1, 4000, 1))).float() 
y_tr =  torch.from_numpy(np.reshape(y_train, (1, 4000, 1))).float() 

x_v =  torch.from_numpy(np.reshape(x_val, (1, 1000, 1))).float() 
y_v =  torch.from_numpy(np.reshape(y_val, (1, 1000, 1))).float() 


grid_search=GS(params, x_tr, y_tr, nn) 
best_loss, best_model=grid_search.min_loss, grid_search.best_model
# print('best loss: ', best_loss, '\n best model: ', best_model)
print('best training loss: ', best_loss)

grid_search_val=GS(params, x_v, y_v, nn) 
best_loss_val, best_model_val=grid_search.min_loss, grid_search.best_model
best_params = best_model_val[0]
# print('Cross validation: \n best loss on validation: ', best_loss_val.item(), '\n best model parametrization based on validation: ',best_params)
# Out:
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.004265058785676956
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.10853990167379379
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0027578873559832573
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007636925205588341
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.0012217320036143064
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.05671020597219467
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.006856378633528948
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007588233333081007
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.0012541867326945066
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.06324608623981476
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0018458669073879719
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 64, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.007694206200540066
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.0015906343469396234
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.03885108232498169
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.007436727173626423
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 5, 'hiddens': 128, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.008144197054207325
# -----------------------------------------------------
# best training loss:  0.0012217320036143064
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'lr': 0.001, 'opt': 'adam'}
# Loss: 0.004196302965283394
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'lr': 0.001, 'opt': 'sgd'}
# Loss: 0.045596662908792496
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'lr': 0.01, 'opt': 'adam'}
# Loss: 0.0033944440074265003
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 64, 'lr': 0.01, 'opt': 'sgd'}
# Loss: 0.006716100499033928
# -----------------------------------------------------
# Parameters: {'epochs': 100, 'layers': 2, 'hiddens': 128, 'lr': 0.001, 'opt': 'adam'}

# %%
print('Cross validation: \n best loss on validation: ', best_loss_val, '\n best model parametrization based on validation: ',best_params)

# %% [markdown]
# ##### Final steps

# %%
x_t =  torch.from_numpy(np.reshape(x_test, (1, 5000, 1))).float() 
y_t =  torch.from_numpy(np.reshape(y_test, (1, 5000, 1))).float() 

# whole_x =  torch.from_numpy(np.reshape(np.concatenate([x_train, x_val]), (1, 5000, 1))).float() 
# whole_y =  torch.from_numpy(np.reshape(np.concatenate([y_train, y_val]), (1, 5000, 1))).float() 
whole_x =  torch.from_numpy(np.reshape(x_whole, (1, 5000, 1))).float() 
whole_y =  torch.from_numpy(np.reshape(y_whole, (1, 5000, 1))).float() 

mse = MSELoss()

print('Loss on whole training set:')

rnn = RNN_model(whole_x.size(0), best_params['layers'], best_params['epochs'], best_params['hiddens'])
optimizer = GS.get_optimizer(rnn, best_params['opt'], best_params['lr'])  
# whole_loss_rnn, whole_ypred=rnn.train(whole_x, whole_y,optimizer) 
whole_ypred= rnn.forward(whole_x)
whole_loss = mse(whole_ypred, whole_y)
print(whole_loss.item())

print('Test loss')
rnn = RNN_model(x_t.size(0), best_params['layers'], best_params['epochs'], best_params['hiddens'])
optimizer = GS.get_optimizer(rnn, best_params['opt'], best_params['lr'])  
# test_loss_rnn, test_ypred=rnn.train(x_t, y_t,optimizer) 
test_ypred= rnn.forward(x_t)
test_loss = mse(test_ypred, y_t)
print(test_loss.item())

# print('Best loss: \n Whole training set: ', whole_loss.item(), '\n Test: ', test_loss.item())

# %%
whole_ypred_NP = whole_ypred.detach().numpy().flatten()
test_ypred_NP = test_ypred.detach().numpy().flatten()

whole_y_NP = whole_y.detach().numpy().flatten()
y_t_NP=y_t.detach().numpy().flatten()

# %%
plot_results(whole_y_NP, whole_ypred_NP, y_t_NP, test_ypred_NP, nn)

# %%
# loss_plot(whole_loss_rnn, test_loss_rnn)
